# %%
import keras
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 1s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
y_train.shape
# Out:
# (60000,)

# %%
x_test.shape
# Out:
# (10000, 28, 28)

# %%
y_train.shape
# Out:
# (60000,)

# %%
plt.figure(figsize=(12, 15))
for i in range(100):
    plt.subplot(10, 10, i+1)
    plt.title('Label: ' + str(i))
    plt.imshow(x_train[i].reshape(28, 28), cmap=None)

# %%
x_train = x_train.reshape((60000, 28 * 28))
x_train = x_train.astype('float32') / 255

x_test = x_test.reshape((10000, 28 * 28))
x_test = x_test.astype('float32') / 255

# %%
def plot_history(history):
    # 精度の履歴をプロット
    plt.plot(history.history['accuracy'],"o-",label="accuracy")
    plt.plot(history.history['val_accuracy'],"o-",label="val_acc")
    plt.title('model accuracy')
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.legend(loc="lower right")
    plt.show()
 
    # 損失の履歴をプロット
    plt.plot(history.history['loss'],"o-",label="loss",)
    plt.plot(history.history['val_loss'],"o-",label="val_loss")
    plt.title('model loss')
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.legend(loc='lower right')
    plt.show()

# %%
from keras.models import Sequential
from keras.layers import Activation, Dense, Dropout
from keras.optimizers import RMSprop

# %%
model = keras.models.Sequential()

# %%
model.add(Dense(units=1024, input_dim=28*28))
model.add(Activation('relu'))
model.add(Dropout(0.2))
model.add(Dense(units=10))
model.add(Activation('softmax'))
model.compile(loss='sparse_categorical_crossentropy', optimizer=RMSprop(), metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, batch_size=64, epochs=50, verbose=1, validation_data=(x_test, y_test))
# Out:
# Epoch 1/50
# 938/938 [==============================] - 7s 8ms/step - loss: 0.2190 - accuracy: 0.9413 - val_loss: 0.4648 - val_accuracy: 0.8929
# Epoch 2/50
# 938/938 [==============================] - 8s 8ms/step - loss: 0.2383 - accuracy: 0.9378 - val_loss: 0.4532 - val_accuracy: 0.8877
# Epoch 3/50
# 938/938 [==============================] - 7s 8ms/step - loss: 0.2570 - accuracy: 0.9330 - val_loss: 0.4676 - val_accuracy: 0.8888
# Epoch 4/50
# 938/938 [==============================] - 7s 7ms/step - loss: 0.2462 - accuracy: 0.9353 - val_loss: 0.4727 - val_accuracy: 0.8797
# Epoch 5/50
# 938/938 [==============================] - 7s 8ms/step - loss: 0.2579 - accuracy: 0.9329 - val_loss: 0.4773 - val_accuracy: 0.8828
# Epoch 6/50
# 938/938 [==============================] - 7s 7ms/step - loss: 0.2653 - accuracy: 0.9308 - val_loss: 0.4670 - val_accuracy: 0.8858
# Epoch 7/50
# 938/938 [==============================] - 7s 7ms/step - loss: 0.2753 - accuracy: 0.9299 - val_loss: 0.4675 - val_accuracy: 0.8869
# Epoch 8/50
# 938/938 [==============================] - 7s 7ms/step - loss: 0.2820 - accuracy: 0.9271 - val_loss: 0.4521 - val_accuracy: 0.8918
# Epoch 9/50
# 938/938 [==============================] - 7s 7ms/step - loss: 0.2693 - accuracy: 0.9300 - val_loss: 0.4592 - val_accuracy: 0.8924
# Epoch 10/50
# 938/938 [==============================] - 7s 7ms/step - loss: 0.2625 - accuracy: 0.9332 - val_loss: 0.4886 - val_accuracy: 0.8868
# Epoch 11/50
# 938/938 [==============================] - 7s 7ms/step - loss: 0.2584 - accuracy: 0.9330 - val_loss: 0.4694 - val_accuracy: 0.8925
# Epoch 12/50
# 938/938 [==============================] - 7s 7ms/step - loss: 0.2782 - accuracy: 0.9284 - val_loss: 0.4520 - val_accuracy: 0.8914
# Epoch 13/50
# 938/938 [==============================] - 7s 7ms/step - loss: 0.2733 - accuracy: 0.9300 - val_loss: 0.4661 - val_accuracy: 0.8869
# Epoch 14/50
# 938/938 [==============================] - 7s 7ms/step - loss: 0.2645 - accuracy: 0.9316 - val_loss: 0.4497 - val_accuracy: 0.8917
# Epoch 15/50
# 938/938 [==============================] - 7s 7ms/step - loss: 0.2562 - accuracy: 0.9351 - val_loss: 0.4434 - val_accuracy: 0.8876
# Epoch 16/50
# 938/938 [==============================] - 7s 7ms/step - loss: 0.2809 - accuracy: 0.9299 - val_loss: 0.4690 - val_accuracy: 0.8851
# Epoch 17/50
# 938/938 [==============================] - 8s 9ms/step - loss: 0.2812 - accuracy: 0.9286 - val_loss: 0.4918 - val_accuracy: 0.8890
# Epoch 18/50
# 938/938 [==============================] - 8s 9ms/step - loss: 0.2644 - accuracy: 0.9333 - val_loss: 0.4989 - val_accuracy: 0.8796
# Epoch 19/50
# 938/938 [==============================] - 10s 11ms/step - loss: 0.2670 - accuracy: 0.9323 - val_loss: 0.4909 - val_accuracy: 0.8828
# Epoch 20/50
# 938/938 [==============================] - 8s 8ms/step - loss: 0.2741 - accuracy: 0.9308 - val_loss: 0.4837 - val_accuracy: 0.8866
# Epoch 21/50
# 938/938 [==============================] - 6s 7ms/step - loss: 0.2685 - accuracy: 0.9313 - val_loss: 0.4511 - val_accuracy: 0.8927
# Epoch 22/50
# 938/938 [==============================] - 7s 7ms/step - loss: 0.2786 - accuracy: 0.9297 - val_loss: 0.4446 - val_accuracy: 0.8941
# Epoch 23/50
# 938/938 [==============================] - 7s 7ms/step - loss: 0.2792 - accuracy: 0.9296 - val_loss: 0.4555 - val_accuracy: 0.8884
# Epoch 24/50
# 938/938 [==============================] - 6s 7ms/step - loss: 0.2873 - accuracy: 0.9277 - val_loss: 0.4524 - val_accuracy: 0.8896
# Epoch 25/50
# 938/938 [==============================] - 6s 7ms/step - loss: 0.2800 - accuracy: 0.9291 - val_loss: 0.5124 - val_accuracy: 0.8772
# Epoch 26/50
# 938/938 [==============================] - 6s 7ms/step - loss: 0.2802 - accuracy: 0.9296 - val_loss: 0.4603 - val_accuracy: 0.8889
# Epoch 27/50
# 938/938 [==============================] - 6s 7ms/step - loss: 0.2754 - accuracy: 0.9309 - val_loss: 0.4652 - val_accuracy: 0.8906
# Epoch 28/50
# 938/938 [==============================] - 6s 7ms/step - loss: 0.2767 - accuracy: 0.9312 - val_loss: 0.4502 - val_accuracy: 0.8927
# Epoch 29/50
# 938/938 [==============================] - 6s 7ms/step - loss: 0.2626 - accuracy: 0.9347 - val_loss: 0.4523 - val_accuracy: 0.8891
# Epoch 30/50
# 938/938 [==============================] - 6s 7ms/step - loss: 0.2759 - accuracy: 0.9317 - val_loss: 0.4730 - val_accuracy: 0.8914
# Epoch 31/50
# 938/938 [==============================] - 8s 9ms/step - loss: 0.2822 - accuracy: 0.9311 - val_loss: 0.4820 - val_accuracy: 0.8816
# Epoch 32/50
# 938/938 [==============================] - 7s 8ms/step - loss: 0.2924 - accuracy: 0.9275 - val_loss: 0.4599 - val_accuracy: 0.8954
# Epoch 33/50
# 938/938 [==============================] - 7s 8ms/step - loss: 0.2818 - accuracy: 0.9308 - val_loss: 0.4780 - val_accuracy: 0.8884
# Epoch 34/50
# 938/938 [==============================] - 7s 8ms/step - loss: 0.2749 - accuracy: 0.9319 - val_loss: 0.4611 - val_accuracy: 0.8871
# Epoch 35/50
# 938/938 [==============================] - 7s 8ms/step - loss: 0.2830 - accuracy: 0.9295 - val_loss: 0.4697 - val_accuracy: 0.8914
# Epoch 36/50
# 938/938 [==============================] - 7s 8ms/step - loss: 0.2820 - accuracy: 0.9316 - val_loss: 0.4500 - val_accuracy: 0.8950
# Epoch 37/50
# 938/938 [==============================] - 7s 8ms/step - loss: 0.2838 - accuracy: 0.9309 - val_loss: 0.4543 - val_accuracy: 0.8927
# Epoch 38/50
# 938/938 [==============================] - 8s 8ms/step - loss: 0.2924 - accuracy: 0.9288 - val_loss: 0.4592 - val_accuracy: 0.8918
# Epoch 39/50
# 938/938 [==============================] - 13s 14ms/step - loss: 0.2895 - accuracy: 0.9286 - val_loss: 0.4728 - val_accuracy: 0.8843
# Epoch 40/50
# 938/938 [==============================] - 8s 9ms/step - loss: 0.2915 - accuracy: 0.9286 - val_loss: 0.4616 - val_accuracy: 0.8947
# Epoch 41/50
# 938/938 [==============================] - 14s 15ms/step - loss: 0.2977 - accuracy: 0.9265 - val_loss: 0.4740 - val_accuracy: 0.8867
# Epoch 42/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2977 - accuracy: 0.9259 - val_loss: 0.4896 - val_accuracy: 0.8868
# Epoch 43/50
# 938/938 [==============================] - 7s 7ms/step - loss: 0.2890 - accuracy: 0.9303 - val_loss: 0.4876 - val_accuracy: 0.8909
# Epoch 44/50
# 938/938 [==============================] - 7s 7ms/step - loss: 0.2954 - accuracy: 0.9286 - val_loss: 0.5018 - val_accuracy: 0.8827
# Epoch 45/50
# 938/938 [==============================] - 8s 8ms/step - loss: 0.2986 - accuracy: 0.9271 - val_loss: 0.4997 - val_accuracy: 0.8879
# Epoch 46/50
# 938/938 [==============================] - 7s 7ms/step - loss: 0.2882 - accuracy: 0.9290 - val_loss: 0.4819 - val_accuracy: 0.8890
# Epoch 47/50
# 938/938 [==============================] - 7s 7ms/step - loss: 0.2829 - accuracy: 0.9310 - val_loss: 0.4911 - val_accuracy: 0.8848
# Epoch 48/50
# 938/938 [==============================] - 8s 8ms/step - loss: 0.2760 - accuracy: 0.9327 - val_loss: 0.4680 - val_accuracy: 0.8899
# Epoch 49/50
# 938/938 [==============================] - 9s 10ms/step - loss: 0.2802 - accuracy: 0.9325 - val_loss: 0.4913 - val_accuracy: 0.8899
# Epoch 50/50
# 938/938 [==============================] - 7s 8ms/step - loss: 0.2756 - accuracy: 0.9327 - val_loss: 0.5215 - val_accuracy: 0.8790

# %%
plot_history(history)

# %%
score = model.evaluate(x_test, y_test, verbose=1)
 
print('loss=', score[0])
print('accuracy=', score[1])
# Out:
# 313/313 [==============================] - 0s 2ms/step - loss: 0.4363 - accuracy: 0.8927
# loss= 0.4363460838794708
# accuracy= 0.8927000164985657

# %%
import numpy as np
from sklearn.metrics import confusion_matrix
 
predict_classes = model.predict_classes(x_test)
true_classes = y_test
print(confusion_matrix(true_classes, predict_classes))
# Out:
# [[779   1   7  20   3   1 181   0   8   0]
#  [  3 981   0   9   3   0   3   0   1   0]
#  [ 12   2 814   6  83   0  82   0   1   0]
#  [ 20   9   8 901  34   1  26   0   1   0]
#  [  0   0  92  19 830   0  58   0   1   0]
#  [  0   0   0   1   0 949   0  22   0  28]
#  [ 76   1  63  24  58   0 772   0   6   0]
#  [  0   0   0   0   0   5   0 973   1  21]
#  [  4   0   9   4   5   1   5   4 968   0]
#  [  0   0   0   0   0   2   1  37   0 960]]

# %%
import pandas as pd
import seaborn as sn
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
 
def print_cmx(y_true, y_pred):
    labels = sorted(list(set(y_true)))
    cmx_data = confusion_matrix(y_true, y_pred, labels=labels)
    
    df_cmx = pd.DataFrame(cmx_data, index=labels, columns=labels)
 
    plt.figure(figsize = (12,7))
    sn.heatmap(df_cmx, annot=True, fmt='g' ,square = True)
    plt.show()
 
print_cmx(true_classes, predict_classes)
