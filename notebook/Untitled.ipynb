# %%
import keras
import matplotlib.pyplot as plt
import faiss

# %matplotlib inline

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.fashion_mnist.load_data()

# %%
plt.figure(figsize=(12, 15))
plt.imshow(x_train[100])

# %%
index = faiss.IndexFlatL2(784)

# %%
reshape_train = x_train.reshape((60000, 28 * 28)).astype('float32') / 255

# %%
reshape_test = x_test.reshape((10000, 28 * 28)).astype('float32') / 255

# %%
faiss.normalize_L2(reshape_x)

# %%
index.add(reshape_x)

# %%
result = index.search(reshape_test, k=10)

# %%
for y in range(50):
    plt.figure(figsize=(1, 1))
    plt.imshow(x_test[y].reshape(28, 28))
    plt.figure(figsize=(12, 15))
    for z, i in enumerate(result[1][y]):
        plt.subplot(10, 10, z+1)
        plt.title('Label: ' + str(z))
        plt.imshow(x_train[i].reshape(28, 28), cmap=None)
# Out:
# <ipython-input-139-6372a7ed03e8>:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure(figsize=(1, 1))
